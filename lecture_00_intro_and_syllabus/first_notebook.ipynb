# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# <span style="color:red"> <font size = "50"> This is my first Jupyter notebook</span>
# #### This is my first Jupyter notebook
# ###### This is my first Jupyter notebook

# %%
print("My name is Daniyal Khan")
# Out:
# My name is Daniyal Khan
